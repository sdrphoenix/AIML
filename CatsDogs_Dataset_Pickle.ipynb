# %%
# Reference https://pythonprogramming.net/loading-custom-data-deep-learning-python-tensorflow-keras/
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DIR = "C:\Sudheer\AIML\datasets\PetImages"
CATEGORIES = ["cats","dogs"]

# %%
# for category in CATEGORIES:
#     path = os.path.join(DIR,category)
#     #print(path)
#     for img in os.listdir(path):
#         img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
#         print(img)
#         print(img_array)
#         plt.imshow(img_array,cmap="gray")
#         plt.show()
#         break
#     break
# print(img_array.shape)
# Out:
# 0.jpg
# [[167 167 168 ... 204 203 202]
#  [167 167 168 ... 204 203 203]
#  [167 167 168 ... 205 204 203]
#  ...
#  [124 124 124 ...   2   2   2]
#  [123 123 123 ...   1   1   1]
#  [122 122 123 ...   1   1   1]]
# (375, 500)

# %%
IMG_SIZE = 80
new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
plt.imshow(new_array,cmap="gray")
plt.show()

# %%
training_data = []

# %%
def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DIR,category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                training_data.append([new_array,class_num])
            except Exception as e:
                pass

create_training_data()

# %%
print(len(training_data))
# Out:
# 100

# %%
import random
random.shuffle(training_data)

# %%
for sample in training_data[:5]:
    print(sample[1])
# Out:
# 1
# 1
# 0
# 0
# 0

# %%
X=[]
y=[]

# %%
for features,label in training_data:
    X.append(features)
    y.append(label)

# %%
X = np.array(X).reshape(-1,IMG_SIZE,IMG_SIZE,1)

# %%
X.shape
# Out:
# (100, 80, 80, 1)

# %%
# Write into pickle file
# import pickle

# pickle_out = open("X_short.pickle","wb")
# pickle.dump(X,pickle_out)
# pickle_out.close()

# pickle_out = open("y_short.pickle","wb")
# pickle.dump(y,pickle_out)
# pickle_out.close()

# %%
# pickle_in = open("X_short.pickle","rb")
# X_read = pickle.load(pickle_in)

# pickle_in = open("y_short.pickle","rb")
# y_read = pickle.load(pickle_in)

# %%
# X_read[1]

# %%
# y_read[:5]
